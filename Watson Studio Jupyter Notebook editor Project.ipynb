# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Komolafe Fatai Abiodun**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because it allows me apply expertise in analyzing and interpreting data to solve real-world problems, leveraging advanced tools like machine learning and big data analytics for deeper insights and impactful decision-making as someone with a foundational knowledge in statistics*

# %% [markdown]
# ### Simple Arithmetic Operations

# %%
a = 3

b = 5

# Addition
Sum_result = a + b
print("Addition", Sum_result)

# Subtraction
Subtraction_result = b - a
print("Subtraction", Subtraction_result)

# Multiplication
Multiplication_result = a * b
print("Multiplication", Multiplication_result)

# Division
Division_result = b / a
print("Division", (round(Division_result, 1)))
# Out:
# Addition 8
# Subtraction 2
# Multiplication 15
# Division 1.7

# %% [markdown]
# - Jupyter Notebook
# - Apache Spark
# - Hadoop
#
# 1. R
# 2. Python
# 3. SQL
#
# | Tools | Uses |
# | ----- | ---- |
# | R | It is a statistical programming language used for data analysis, visualization, and statistical modeling. It excels in handling statistical operations, creating sophisticated plots, and developing data models. |
# | Python | It is a versatile programming language widely used for data science, machine learning, web development, and automation. Libraries like NumPy, Pandas, Matplotlib, and Scikit-learn make it a powerhouse for data manipulation, visualization, and building predictive models. |
# | SQL | It is used for managing and querying relational databases. It enables users to extract, update, and analyze structured data stored in tables. Commonly used in data retrieval and preprocessing in data science. |
#
# [R Website](https://www.r-project.org/)
#
# [Python Website](https://www.python.org/)
#
# [SQL Website](https://www.mysql.com/)
#
# R Logo: ![R](https://www.r-project.org/Rlogo.png)
#
# Python Logo: ![Python](https://www.python.org/static/community_logos/python-logo-master-v3-TM-flattened.png)
#
# SQL Logo: ![SQL](https://upload.wikimedia.org/wikipedia/commons/8/87/Sql_data_base_with_logo.png)
